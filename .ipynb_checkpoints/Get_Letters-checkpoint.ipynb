# %%
import glob
import pandas as pd

newspapers = ['AJC', 'DP', 'DMR', 'NYT', 'OS', 'SFC']
schools = ['Amish', 'AZU', 'CE', 'CHS', 'KS', 'NIU', 'Oikos', 'RLSHS', 'SHE', 'UCC', 'VT', 'WSM']


for i in range(len(newspapers)):
    top_folder = newspapers[i] + '_clean'
    print(top_folder)
    for j in range(len(schools)):
        letter_data = []
        bottom_folder = top_folder + '/' + schools[j]
        print(bottom_folder)
    for file in glob.iglob(bottom_folder, recursive=True):
        letter_date = file[0:7]
        letter_data = open(file, "r")
        for line in letter_data:
            try:
                letter_data.append(line)
            except:
                continue
        print(newspaper[i])
        print(schools[j])
        print(letter_date)
# Out:
# AJC_clean
# AJC_clean/Amish
# AJC_clean/AZU
# AJC_clean/CE
# AJC_clean/CHS
# AJC_clean/KS
# AJC_clean/NIU
# AJC_clean/Oikos
# AJC_clean/RLSHS
# AJC_clean/SHE
# AJC_clean/UCC
# AJC_clean/VT
# AJC_clean/WSM
# DP_clean
# DP_clean/Amish
# DP_clean/AZU
# DP_clean/CE
# DP_clean/CHS
# DP_clean/KS
# DP_clean/NIU
# DP_clean/Oikos
# DP_clean/RLSHS
# DP_clean/SHE
# DP_clean/UCC
# DP_clean/VT
# DP_clean/WSM
# DMR_clean
# DMR_clean/Amish
# DMR_clean/AZU
# DMR_clean/CE
# DMR_clean/CHS
# DMR_clean/KS
# DMR_clean/NIU
# DMR_clean/Oikos
# DMR_clean/RLSHS
# DMR_clean/SHE
# DMR_clean/UCC
# DMR_clean/VT
# DMR_clean/WSM
# NYT_clean
# NYT_clean/Amish
# NYT_clean/AZU
# NYT_clean/CE
# NYT_clean/CHS
# NYT_clean/KS
# NYT_clean/NIU
# NYT_clean/Oikos
# NYT_clean/RLSHS
# NYT_clean/SHE
# NYT_clean/UCC
# NYT_clean/VT
# NYT_clean/WSM
# OS_clean
# OS_clean/Amish
# OS_clean/AZU
# OS_clean/CE
# OS_clean/CHS
# OS_clean/KS
# OS_clean/NIU
# OS_clean/Oikos
# OS_clean/RLSHS
# OS_clean/SHE
# OS_clean/UCC
# OS_clean/VT
# OS_clean/WSM
# SFC_clean
# SFC_clean/Amish
# SFC_clean/AZU
# SFC_clean/CE
# SFC_clean/CHS
# SFC_clean/KS
# SFC_clean/NIU
# SFC_clean/Oikos
# SFC_clean/RLSHS
# SFC_clean/SHE
# SFC_clean/UCC
# SFC_clean/VT
# SFC_clean/WSM
