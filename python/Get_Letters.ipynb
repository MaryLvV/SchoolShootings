# %%
import glob
import pandas as pd

newspapers = ['AJC', 'DeP', 'DMR', 'NYT', 'OrS', 'SFC']
schools = ['AMI', 'CHS', 'SHE', 'UCC', 'VaT']
letters = pd.DataFrame(columns = ('letter', 'datetime', 'source', 'event'))

for i in range(len(newspapers)):
    top_folder = newspapers[i] + '_clean'

    for j in range(len(schools)):
        bottom_folder = top_folder + '/' + schools[j] + '/*.txt'

        for file in glob.iglob(bottom_folder, recursive=True):
            letter_date = file[14:22]
            letter_file = open(file, "r")
            
            for line in letter_file:
                letters.loc[len(letters)] = [line, letter_date, newspapers[i], schools[j]]

# %%
letters
# Out:
#                                                 letter  datetime source event
# 0    The Atlanta Journal-Constitution's front page ...  10042006    AJC   AMI
# 1    The Amish bury their dead. Young girls execute...  10092006    AJC   AMI
# 2    The horrific evil of the Pennsylvania school m...  10092006    AJC   AMI
# 3    What happened Saturday in rural Pennsylvania s...  10102006    AJC   AMI
# 4    The Amish mourn the killer. I wonder how many ...  10102006    AJC   AMI
# 5    In response to the violent tragedy at Columbin...  04221999    AJC   CHS
# 6    The lack of Judeo-Christian family values caus...  04221999    AJC   CHS
# 7    Perhaps National Rifle Association President C...  04221999    AJC   CHS
# 8    I was sitting in my computer class and I start...  04231999    AJC   CHS
# 9    The carnage at Columbine High School horrified...  04231999    AJC   CHS
# 10   What makes kids think that they can solve thei...  04231999    AJC   CHS
# 11   Didn't they think about all the innocent peopl...  04231999    AJC   CHS
# 12   I am only 15 and I really feel like I have a l...  04231999    AJC   CHS
# 13   Many of the articles, columns and editorials p...  04251999    AJC   CHS
# 14   It shouldn't take a panel of experts to unders...  04261999    AJC   CHS
# 15   Much of the conversation after the Columbine H...  04261999    AJC   CHS
# 16   The shootings at Columbine High School have re...  04271999    AJC   CHS
# 17   Although I am outraged at the senseless murder...  05011999    AJC   CHS
# 18   As a parent of a high school student, I was ho...  05031999    AJC   CHS
# 19   Gun control whiners are calling for more gun c...  05061999    AJC   CHS
# 20   The recent horror at Columbine High School has...  05061999    AJC   CHS
# 21   A stunned and bewildered nation shakes its hea...  05071999    AJC   CHS
# 22   The Columbine High School massacre baffles our...  05131999    AJC   CHS
# 23   In the days after the massacre at the high sch...  05171999    AJC   CHS
# 24   To help head off a horrible tragedy in Georgia...  05191999    AJC   CHS
# 25   Wayne LaPierre and the NRA missed the mark at ...  01042013    AJC   SHE
# 26   Imagine how much faster the shootings at Colum...  01072013    AJC   SHE
# 27   In the wake of the Sandy Hook Elementary Schoo...  01092013    AJC   SHE
# 28   Stricter controls on gun sales, an assault wea...  12212012    AJC   SHE
# 29   Count your blessings if you've never been impa...  12212012    AJC   SHE
# ..                                                 ...       ...    ...   ...
# 568  Someone please explain to me how the NRA's pla...  12222012    SFC   SHE
# 569  It is time to repeal the Second Amendment. As ...  12222012    SFC   SHE
# 570  When pizzas are outlawed, only outlaws will ha...  12222012    SFC   SHE
# 571  What will it take?At some point in American hi...  12225201    SFC   SHE
# 572  Empathy and frustration has emerged from insid...  10072015    SFC   UCC
# 573  In "Time to limit the access to firearm" (Lett...  10092015    SFC   UCC
# 574  "Time to limit the access to firearms" (Letter...  10092015    SFC   UCC
# 575  The NRA has found itself boxed into a corner; ...  10092015    SFC   UCC
# 576  Once again, a madman with a gun has taken too ...  04172007    SFC   VaT
# 577  Could anything be more shocking than this? Who...  04172007    SFC   VaT
# 578  I would like to say to any politician who pand...  04172007    SFC   VaT
# 579  Thirty-two innocent people senselessly murdere...  04172007    SFC   VaT
# 580  While I was shocked and horrified when I saw t...  04172007    SFC   VaT
# 581  "The president believes that there is a right ...  04172007    SFC   VaT
# 582  Every time something tragic occurs in this cou...  04182007    SFC   VaT
# 583  Let's step back from accusing the university o...  04182007    SFC   VaT
# 584  Chris Breyer states that the 32 people killed ...  04182007    SFC   VaT
# 585  Tom Meyer's editorial cartoon in the April 17 ...  04182007    SFC   VaT
# 586  It struck me that the artist, without realizin...  04182007    SFC   VaT
# 587  I can guarantee you that if even a few of the ...  04182007    SFC   VaT
# 588  The predictable outrage greets us this morning...  04182007    SFC   VaT
# 589  According to criminologist Gary Kleck, a oneti...  04182007    SFC   VaT
# 590  Already in the wake of the Virginia Tech trage...  04182007    SFC   VaT
# 591  In 1966, a few months after my own graduation ...  04182007    SFC   VaT
# 592  I am writing to urge you not to exploit the re...  04192007    SFC   VaT
# 593  Wouldn't we all be safer if every psychologica...  04192007    SFC   VaT
# 594  The measurable difference between a "moody art...  04192007    SFC   VaT
# 595  Massacres, along with racism, sexism, war and ...  04192007    SFC   VaT
# 596  I never thought I would praise Debra J. Saunde...  04202007    SFC   VaT
# 597  Re the May 1 article, "Green stickers point wa...  05142007    SFC   VaT
#
# [598 rows x 4 columns]

# %%
import feather
feather.write_dataframe(letters, './letters.feather')
